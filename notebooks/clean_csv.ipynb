# %%
import pandas as pd

df = pd.read_csv("data/restaurants_and_hospitals_details.csv")

df.head()
# Out:
#                                              address         categories/0  \
# 0  V269+CHC, MA Jinnah Rd, Saddar Town, Karachi, ...  Government hospital
# 1  V269+CHC, MA Jinnah Rd, Saddar Town, Karachi, ...  Government hospital
# 2  V269+CHC, MA Jinnah Rd, Saddar Town, Karachi, ...  Government hospital
# 3  V269+CHC, MA Jinnah Rd, Saddar Town, Karachi, ...  Government hospital
# 4  V269+CHC, MA Jinnah Rd, Saddar Town, Karachi, ...  Government hospital
#
#   categories/1 categories/2 categories/3         categoryName  \
# 0          NaN          NaN          NaN  Government hospital
# 1          NaN          NaN          NaN  Government hospital
# 2          NaN          NaN          NaN  Government hospital
# 3          NaN          NaN          NaN  Government hospital
# 4          NaN          NaN          NaN  Government hospital
#
#                    cid     city countryCode error  ... state  \
# 0  1666631275229222110  Karachi          PK   NaN  ...   NaN
# ...
